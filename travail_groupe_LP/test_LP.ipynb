# %%
from SecondOrderElec import LP
from SecondOrderElec.plot import plot_bode
import matplotlib.pyplot as plt
import numpy as np

# %%
f0=1005
T0=1
m=0.1

# %%
w0 = f0*2*np.pi
for m in [
    0.1,0.5,1,2
]:
    print(f"m: {m}")
    filter_instance = LP(T0, m, w0)
    filter_instance.freqresp()
# Out:
# m: 0.1
# m: 0.5
# m: 1
# m: 2
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# > test
# >> test
# > test
